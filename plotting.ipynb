# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

distances_3 = np.linspace(0, 30, 50)
ratios_3 = np.linspace(0.01, 0.5, 50)

auc_simple_guess_method = pd.read_csv(r"C:\Users\Gebruiker\XENONnT_pmt_statistics\csvs\auc_results_simple_guess.csv")
auc_results_machine_learning_method = pd.read_csv(r"C:\Users\Gebruiker\XENONnT_pmt_statistics\csvs\auc_results_machine_learning_50_50.csv")
auc_results_ellipse_method = pd.read_csv(r"C:\Users\Gebruiker\XENONnT_pmt_statistics\csvs\auc_results_ellipse_guess.csv")
#Make contour plot for all 3 separately
plt.figure(figsize=(18, 5))
#Chi-squared method
plt.subplot(1, 3, 1)
X, Y = np.meshgrid(ratios_3, distances_3)
Z = auc_simple_guess_method.values  # Assuming the AUC values are in the csv
contour = plt.contourf(X, Y, Z, levels=50, cmap='coolwarm')
plt.colorbar(contour)
plt.xlabel('Ratio')
plt.ylabel('Distance (cm)')
plt.title('AUC Contour Plot for Simple Guess Method')
#Simple guess method
plt.subplot(1, 3, 2)
X, Y = np.meshgrid(ratios_3, distances_3)
Z = auc_results_machine_learning_method.values  # Assuming the AUC values are in the csv
contour = plt.contourf(X, Y, Z, levels=50, cmap='coolwarm')
plt.colorbar(contour)
plt.xlabel('Ratio')
plt.ylabel('Distance (cm)')
plt.title('AUC Contour Plot for Machine Learning Method')
#Machine learning method
plt.subplot(1, 3, 3)
X, Y = np.meshgrid(ratios_3, distances_3)
Z = auc_results_ellipse_method.values  # Assuming the AUC values are in the csv
contour = plt.contourf(X, Y, Z, levels=50, cmap='coolwarm')
plt.colorbar(contour)
plt.xlabel('Ratio')
plt.ylabel('Distance (cm)')
plt.title('AUC Contour Plot for Ellipse Method')
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.ndimage import gaussian_filter
import matplotlib.lines as mlines

plt.figure(figsize=(10, 6))
X2, Y2 = np.meshgrid(ratios_2, distances_2)
X3, Y3 = np.meshgrid(ratios_3, distances_3)

methods = [
    (auc_chi_squared_method.values,              X2, Y2, 'Chi-Squared Statistic',     'blue'),
    (auc_simple_guess_method.values,             X3, Y3, 'Simple Guess',     'red'),
    (auc_results_machine_learning_method.values, X3, Y3, 'Machine Learning Guess', 'green'),
    (auc_results_ellipse_method.values,          X3, Y3, 'Ellipse Guess',          'orange'),
]

legend_handles = []
for Z, X, Y, label, color in methods:
    Z_smooth = gaussian_filter(Z, sigma=2)
    plt.contour(X, Y, Z_smooth, levels=[0.7], colors=color, linestyles='dashed', linewidths=1.5)
    plt.contour(X, Y, Z_smooth, levels=[0.9], colors=color, linestyles='solid',  linewidths=1.5)
    # Manually build legend entries
    legend_handles.append(mlines.Line2D([], [], color=color, linestyle='dashed', linewidth=1.5, label=f'{label} (70%)'))
    legend_handles.append(mlines.Line2D([], [], color=color, linestyle='solid',  linewidth=1.5, label=f'{label} (90%)'))

plt.xlabel('Ratio')
plt.ylabel('Distance (cm)')
plt.title('AUC Contour Lines by Method')
plt.legend(handles=legend_handles, loc='upper right')
plt.grid(True, alpha=0.3)
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

auc_chi_squared_method = pd.read_csv(r"C:\Users\Gebruiker\XENONnT_pmt_statistics\csvs\auc_results.csv")
distances_2 = np.linspace(0, 30, 150)  # Example distances from 0 to 30 cm
ratios_2 = np.linspace(0.01, 0.5, 100)  # Example ratios from 0.1 to 0.5
#Making contour plot of AUC values for chi-squared method
plt.figure(figsize=(10, 6))
X, Y = np.meshgrid(ratios_2, distances_2)
Z = auc_chi_squared_method.values  # Assuming the AUC values are in the csv
contour = plt.contourf(X, Y, Z, levels=50, cmap='coolwarm')
#with smooth contour lines at AUC values of 0.6, 0.7, 0.8 and 0.9
plt.contour(X, Y, Z, levels=[0.6, 0.7, 0.8, 0.9], colors='black', linestyles='dashed')
plt.colorbar(contour)
plt.xlabel('Ratio')
plt.ylabel('Distance (cm)')
plt.title('AUC Contour Plot for Chi-Squared Method')
plt.show()

distances_3 = np.linspace(0, 30, 50)
ratios_3 = np.linspace(0.01, 0.5, 50)

auc_simple_guess_method = pd.read_csv(r"C:\Users\Gebruiker\XENONnT_pmt_statistics\csvs\auc_results_simple_guess.csv")
auc_results_machine_learning_method = pd.read_csv(r"C:\Users\Gebruiker\XENONnT_pmt_statistics\csvs\auc_results_machine_learning_50_50.csv")
auc_results_ellipse_method = pd.read_csv(r"C:\Users\Gebruiker\XENONnT_pmt_statistics\csvs\auc_results_ellipse_guess.csv")

#plot 3 others separately

plt.figure(figsize=(10, 6))
X, Y = np.meshgrid(ratios_3, distances_3)
Z = auc_simple_guess_method.values  # Assuming the AUC values are in the csv
contour = plt.contourf(X, Y, Z, levels=50, cmap='coolwarm')
#with smooth contour lines at AUC values of 0.6, 0.7, 0.8 and 0.9
plt.contour(X, Y, Z, levels=[0.6, 0.7, 0.8, 0.9], colors='black', linestyles='dashed')
plt.colorbar(contour)
plt.xlabel('Ratio')
plt.ylabel('Distance (cm)')
plt.title('AUC Contour Plot for Simple Guess Method')
plt.show()

plt.figure(figsize=(10, 6))
X, Y = np.meshgrid(ratios_3, distances_3)
Z = auc_results_machine_learning_method.values  # Assuming the AUC values are in the csv
contour = plt.contourf(X, Y, Z, levels=50, cmap='coolwarm')
#with smooth contour lines at AUC values of 0.6, 0.7, 0.8 and 0.9
plt.contour(X, Y, Z, levels=[0.6, 0.7, 0.8, 0.9], colors='black', linestyles='dashed')
plt.colorbar(contour)
plt.xlabel('Ratio')
plt.ylabel('Distance (cm)')
plt.title('AUC Contour Plot for Machine Learning Method')
plt.show()

plt.figure(figsize=(10, 6))
X, Y = np.meshgrid(ratios_3, distances_3)
Z = auc_results_ellipse_method.values  # Assuming the AUC values are in the csv
contour = plt.contourf(X, Y, Z, levels=50, cmap='coolwarm')
#with smooth contour lines at AUC values of 0.6, 0.7, 0.8 and 0.9
plt.contour(X, Y, Z, levels=[0.6, 0.7, 0.8, 0.9], colors='black', linestyles='dashed')
plt.colorbar(contour)
plt.xlabel('Ratio')
plt.ylabel('Distance (cm)')
plt.title('AUC Contour Plot for Ellipse Method')
plt.show()


#also all 4 in a grid of 2x2 subplots
fig, axes = plt.subplots(2, 2, figsize=(18, 10))
#Chi-squared method
axes[0, 0].contourf(X, Y, Z, levels=50, cmap='coolwarm')
#with smooth contour lines at AUC values of 0.6, 0.7, 0.8 and 0.9
axes[0, 0].contour(X, Y, Z, levels=[0.6, 0.7, 0.8, 0.9], colors='black', linestyles='dashed')
axes[0, 0].set_xlabel('Signal Ratio')
axes[0, 0].set_ylabel('Distance (cm)')
axes[0, 0].set_title('AUC Contour Plot for Chi-Squared Method')
#Simple guess method
axes[0, 1].contourf(X, Y, Z, levels=50, cmap='coolwarm')
#with smooth contour lines at AUC values of 0.6, 0.7, 0.8 and 0.9
axes[0, 1].contour(X, Y, Z, levels=[0.6, 0.7, 0.8, 0.9], colors='black', linestyles='dashed')
axes[0, 1].set_xlabel('Signal Ratio')
axes[0, 1].set_ylabel('Distance (cm)')
axes[0, 1].set_title('AUC Contour Plot for Simple Guess Method')
#Top 2 PMT Guess Profile Likelihood method
axes[1, 0].contourf(X, Y, Z, levels=50, cmap='coolwarm')
#with smooth contour lines at AUC values of 0.6, 0.7, 0.8 and 0.9
axes[1, 0].contour(X, Y, Z, levels=[0.6, 0.7, 0.8, 0.9], colors='black', linestyles='dashed')
axes[1, 0].set_xlabel('Signal Ratio')
axes[1, 0].set_ylabel('Distance (cm)')
axes[1, 0].set_title('AUC Contour Plot for top 2 PMT Guess Profile Likelihood Method')
#Machine learning method
axes[1, 1].contourf(X, Y, Z, levels=50, cmap='coolwarm')
#with smooth contour lines at AUC values of 0.6, 0.7, 0.8 and 0.9
axes[1, 1].contour(X, Y, Z, levels=[0.6, 0.7, 0.8, 0.9], colors='black', linestyles='dashed')
axes[1, 1].set_xlabel('Signal Ratio')
axes[1, 1].set_ylabel('Distance (cm)')
axes[1, 1].set_title('AUC Contour Plot for Machine Learning Method')
axes[1,1].contourf(X, Y, Z, levels=50, cmap='coolwarm')
#with smooth contour lines at AUC values of 0.6, 0.7, 0.8 and 0.9
axes[1,1].contour(X, Y, Z, levels=[0.6, 0.7, 0.8, 0.9], colors='black', linestyles='dashed')
axes[1,1].set_xlabel('Signal Ratio')
axes[1,1].set_ylabel('Distance (cm)')
axes[1,1].set_title('AUC Contour Plot for Machine Learning Guess Profile Likelihood Method')
#Ellipse method
plt.subplot(2, 2, 4)
X, Y = np.meshgrid(ratios_3, distances_3)
Z = auc_results_ellipse_method.values  # Assuming the AUC values are in the csv
contour = plt.contourf(X, Y, Z, levels=50, cmap='coolwarm')
#with smooth contour lines at AUC values of 0.6, 0.7, 0.8 and 0.9
plt.contour(X, Y, Z, levels=[0.6, 0.7, 0.8, 0.9], colors='black', linestyles='dashed')
plt.xlabel('Signal Ratio')
plt.ylabel('Distance (cm)')
plt.title('AUC Contour Plot for Covariance Ellipse Guess Profile Likelihood Method')
plt.tight_layout()

fig.colorbar(contour, ax=axes, location='right', shrink=0.6, label='AUC')
cbar.set_ticks(np.linspace(0.5, 1.0, 11))  # ticks from 0.5 to 1.0
plt.suptitle('AUC Contour Plots for Different Methods', fontsize=16)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 112
#     109 plt.title('AUC Contour Plot for Covariance Ellipse Guess Profile Likelihood Method')
#     110 plt.tight_layout()
# --> 112 fig.colorbar(contour, ax=axes, location='right', shrink=0.6, label='AUC')
#     113 cbar.set_ticks(np.linspace(0.5, 1.0, 11))  # ticks from 0.5 to 1.0
#     114 plt.suptitle('AUC Contour Plots for Different Methods', fontsize=16)
#
# NameError: name 'fig' is not defined

# %%
from matplotlib.colors import LinearSegmentedColormap

cmap = LinearSegmentedColormap.from_list('orange_green', ['darkorange', 'darkgreen'])

fig, axes = plt.subplots(2, 2, figsize=(18, 10))

# Chi-squared method
ax = axes[0, 0]
X, Y = np.meshgrid(ratios_2, distances_2)
Z = auc_chi_squared_method.values
contour = ax.contourf(X, Y, Z, levels=50, cmap='gray', vmin=0.5, vmax=1.0)
ax.contour(X, Y, Z, levels=[0.6, 0.7, 0.8, 0.9], colors='black', linestyles='dashed')
ax.set_xlabel('Signal Ratio')
ax.set_ylabel('Distance (cm)')
ax.set_title('AUC Contour Plot for Chi-Squared Method')

# Simple guess method
ax = axes[0, 1]
X, Y = np.meshgrid(ratios_3, distances_3)
Z = auc_simple_guess_method.values
contour = ax.contourf(X, Y, Z, levels=50, cmap='gray', vmin=0.5, vmax=1.0)
ax.contour(X, Y, Z, levels=[0.6, 0.7, 0.8, 0.9], colors='black', linestyles='dashed')
ax.set_xlabel('Signal Ratio')
ax.set_ylabel('Distance (cm)')
ax.set_title('AUC Contour Plot for top 2 PMT Guess Profile Likelihood Method')

# Machine learning method
ax = axes[1, 0]
X, Y = np.meshgrid(ratios_3, distances_3)
Z = auc_results_machine_learning_method.values
contour = ax.contourf(X, Y, Z, levels=50, cmap='gray', vmin=0.5, vmax=1.0)
ax.contour(X, Y, Z, levels=[0.6, 0.7, 0.8, 0.9], colors='black', linestyles='dashed')
ax.set_xlabel('Signal Ratio')
ax.set_ylabel('Distance (cm)')
ax.set_title('AUC Contour Plot for Machine Learning Guess Profile Likelihood Method')

# Ellipse method
ax = axes[1, 1]
X, Y = np.meshgrid(ratios_3, distances_3)
Z = auc_results_ellipse_method.values
contour = ax.contourf(X, Y, Z, levels=50, cmap='gray', vmin=0.5, vmax=1.0)
ax.contour(X, Y, Z, levels=[0.6, 0.7, 0.8, 0.9], colors='black', linestyles='dashed')
ax.set_xlabel('Signal Ratio')
ax.set_ylabel('Distance (cm)')
ax.set_title('AUC Contour Plot for Covariance Ellipse Guess Profile Likelihood Method')

# Single shared colorbar on the right
fig.colorbar(contour, ax=axes, location='right', shrink=0.6, label='AUC', ticks=np.linspace(0.5, 1.0, 11))

plt.suptitle('AUC Contour Plots for Different Methods', fontsize=14)
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

auc_values = pd.read_csv(r"C:\Users\Gebruiker\XENONnT_pmt_statistics\csvs\auc_results_machine_learning.csv")
distances = np.linspace(0, 20, 5)
ratios = np.array([0.01, 0.02, 0.05, 0.1, 0.2, 0.5])

# Reverse row order so largest distance is at top
auc_values = auc_values.iloc[::-1]

plt.figure(figsize=(10, 6))
sns.heatmap(auc_values, annot=True, cmap='viridis', center=0.5)
plt.xlabel('Ratio')
plt.ylabel('Distance (cm)')
plt.title('AUC Heatmap for Different Ratios and Distances')

# Set y-axis ticks to actual distance values, reversed
plt.yticks(
    ticks=np.arange(len(distances)) + 0.5,
    labels=distances[::-1],
    rotation=0
)

plt.show()
